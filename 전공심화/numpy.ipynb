# %%
import numpy as np

a = np.array(range(1, 11)) + np.array(range(10, 101, 10))
print(a)
print(a.shape)
print(a.size)
# Out:
# [ 11  22  33  44  55  66  77  88  99 110]
# (10,)
# 10

# %%
# 넘파이의 배열 안에는 동일한 타입의 데이터만 저장
# 원하는 위치에 바로 접근하여 데이터를 읽고 쓰는 일을 임의 접근(random access)
# 주기억장치(RAM) = Random Access Memory

# 균일한 확률 분포(uniform distribution) : 분포가 특정 범위 내에서 균등하게 나타나 있을 경우
# 표준정규분포(standard normal distribution) = 평균 : 0, 편차 : 1
# 정규분포(normal distribution) : 평균과 표준편차가 주어져 있을 때 엔트로피를 최대화하는 분포

# 시리즈 : 1차원 구조를 가진 하나의 열
# 데이터프레임 : 복수의 열을 가진 2차원 데이터
# CSV : 쉼표로 구분한 변수comma separated variables

# df_1.merge(df_2, how="outer, inner, left, right", on="조인 연산을 수행하기 위해 사용할 레이블")
# on : 왼쪽/오른쪽 프레임에 모두 존재해야 함

# %%
import numpy as np
import matplotlib.pyplot as plt

a = np.random.randn(100, 10)
plt.boxplot(a)
plt.show()

# %%
fig, ax = plt.subplots(2, 2, figsize=(5, 5))
ax[1, 1].plot(range(10))

# %%
import pandas as pd
import matplotlib.pyplot as plt
import datetime as dt

weather = pd.read_csv("../resources/5장/weather.csv", encoding="CP949")
monthly = [None for _ in range(12)]
monthly_wind = [0 for _ in range(12)]

weather["month"] = pd.DatetimeIndex(weather["date"]).month

for i in range(12):
    monthly[i] = weather[weather["month"] == i + 1]
    # monthly_wind[i] = monthly[i]["mean_wind"].mean()
    means = weather.groupby("month")['mean_wind'].mean()
plt.plot(means, "red")
plt.show()
